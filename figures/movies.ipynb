# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import tifffile

# %%
base_dir = Path(r"D:\FeedbackControl\data\for_movies")

stem = "cycle10.1"
initial = stem + "_patterns.tif"
decay = stem + "_decay_patterns.tif"
fbc = stem + "_fbc_patterns.tif"

arr1 = tifffile.imread(base_dir / initial)[:80]
arr2 = tifffile.imread(base_dir / decay)[7:]
arr3 = tifffile.imread(base_dir / fbc)

arr = np.vstack((arr1, arr2, arr3))

tifffile.imwrite(base_dir / "fbc_vals.tif", arr[:, 0, 400:1200, 400:1200])

# %%
from tqdm import tqdm

for movie in tqdm(base_dir.glob("*.tif")):
    arr = tifffile.imread(movie)
    arr = arr[1:, ..., 400:1200, 400:1200]

    axes = "tcyx" if arr.ndim == 4 else "tyx"

    tifffile.imwrite(
        base_dir / "cropped" / movie.name, arr, imagej=True, metadata={"axes": axes}
    )
# Out:
# 15it [00:33,  2.24s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26516\1160864016.py in ?()
#       5     arr = arr[1:, ..., 400:1200, 400:1200]
#       6
#       7     axes = "tcyx" if arr.ndim == 4 else "tyx"
#       8
# ----> 9     tifffile.imwrite(base_dir / "cropped" / movie.name, arr, imagej=True, metadata={"axes": axes})
#      10
#
# ~\.conda\envs\pyclm-analysis\lib\site-packages\tifffile\tifffile.py in ?(file, data, mode, bigtiff, byteorder, imagej, ome, shaped, append, shape, dtype, photometric, planarconfig, extrasamples, volumetric, tile, rowsperstrip, bitspersample, compression, compressionargs, predictor, subsampling, jpegtables, iccprofile, colormap, description, datetime, resolution, resolutionunit, subfiletype, software, metadata, extratags, contiguous, truncate, align, maxworkers, buffersize, returnoffset)
#    1407         imagej=imagej,
#    1408         ome=ome,
#    1409         shaped=shaped,
#    1410     ) as tif:
# -> 1411         result = tif.write(
#    1412             data,
#    1413             shape=shape,
#    1414             dtype=dtype,
#
# ~\.conda\envs\pyclm-analysis\lib\site-packages\tifffile\tifffile.py in ?(***failed resolving arguments***)
#    2459             if metadata is None:
#    2460                 axes = None
#    2461             else:
#    2462                 axes = metadata.get('axes', None)
# -> 2463             ijshape = imagej_shape(datashape, rgb=ijrgb, axes=axes)
#    2464             if planarconfig == SEPARATE:
#    2465                 raise ValueError(
#    2466                     'the ImageJ format does not support planar samples'
#
# ~\.conda\envs\pyclm-analysis\lib\site-packages\tifffile\tifffile.py in ?(shape, rgb, axes)
#   21339         raise ValueError('ImageJ hyperstack must be 2-6 dimensional')
#   21340
#   21341     if axes:
#   21342         if len(axes) != ndim:
# > 21343             raise ValueError('ImageJ hyperstack shape and axes do not match')
#   21344         i = 0
#   21345         axes = axes.upper()
#   21346         for ax in axes:
#
# ValueError: ImageJ hyperstack shape and axes do not match
